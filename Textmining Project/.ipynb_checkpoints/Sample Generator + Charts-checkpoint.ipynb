# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **GENERATOR PRÓBY**

# %%
df = pd.read_csv("Comments.csv", sep=';')

# %%
date = "2020-12-10"
before = df['comment_date'] < date
after = df['comment_date'] >= date

# %%
df_before = df.loc[before]
df_before = df_before["comment_body"].sample(5000)
df_before.to_csv("comment_body_before.csv", index = False)

# %%
df_after = df.loc[after]
df_after = df_after["comment_body"].sample(5000)
df_after.to_csv("comment_body_after.csv", index = False)

# %% [markdown]
# ### **WYKRESY**

# %%
plt.figure(figsize=(50, 3))

plt.subplot(131)
plt.bar(Część_mowy_After, Wartości_After)
plt.subplot(132)
plt.scatter(Część_mowy_After, Wartości_After)
plt.subplot(133)
plt.plot(Część_mowy_After, Wartości_After)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
df_before = pd.DataFrame(list(zip(Część_mowy_Before,Wartości_Before)), columns = ["Część_mowy","Wartość"])
df_after = pd.DataFrame(list(zip(Część_mowy_After,Wartości_After)), columns = ["Część_mowy","Wartość"])

# %%
before = sns.regplot(
    data = df_before,
    x = "Część_mowy",
    y = "Wartość",
    fit_reg = False,
    marker="o",
    color="skyblue",
    scatter_kws={'s':100})
